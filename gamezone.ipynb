# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\user\OneDrive\桌面\Data Analysis Projects\Python\Gamezone_project\gamezone_data.csv')
df.head()
# Out:
#     USER_ID           ORDER_ID PURCHASE_TS     SHIP_TS  REFUND_TS  \
# 0  2c06175e   0001328c3c220830  12/24/2020  12/13/2020        NaN
# 1  ee8e5bc2  0002af7a5c6100772   10/1/2020   9/21/2020        NaN
# 2  9eb4efe0   0002b8350e167074   4/21/2020   2/16/2020        NaN
# 3  cac7cbaf   0006d06b98385729    4/7/2020    4/4/2020  4/28/2022
# 4  6b0230bc   00097279a2f46150  11/24/2020    8/2/2020        NaN
#
#                 PRODUCT_NAME PRODUCT_ID  USD_PRICE PURCHASE_PLATFORM  \
# 0            Nintendo Switch       e682     168.00           website
# 1            Nintendo Switch       e682     160.61           website
# 2            Nintendo Switch       8d0d     151.20           website
# 3  Sony PlayStation 5 Bundle       54ed    1132.82           website
# 4            Nintendo Switch       8d0d      33.89           website
#
#   MARKETING_CHANNEL ACCOUNT_CREATION_METHOD COUNTRY_CODE  Unnamed: 12  \
# 0         affiliate                 unknown           US          NaN
# 1            direct                 desktop           DE          NaN
# 2            direct                 desktop           US          NaN
# 3            direct                 desktop           AU          NaN
# 4            direct                 desktop           TR          NaN
#
#   Unnamed: 13
# 0      #NAME?
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21864 entries, 0 to 21863
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   USER_ID                  21864 non-null  object
#  1   ORDER_ID                 21864 non-null  object
#  2   PURCHASE_TS              21864 non-null  object
#  3   SHIP_TS                  21864 non-null  object
#  4   REFUND_TS                3488 non-null   object
#  5   PRODUCT_NAME             21864 non-null  object
#  6   PRODUCT_ID               21864 non-null  object
#  7   USD_PRICE                21859 non-null  float64
#  8   PURCHASE_PLATFORM        21864 non-null  object
#  9   MARKETING_CHANNEL        21781 non-null  object
#  10  ACCOUNT_CREATION_METHOD  21781 non-null  object
#  11  COUNTRY_CODE             21826 non-null  object
#  12  Unnamed: 12              0 non-null      float64
#  13  Unnamed: 13              1 non-null      object
# dtypes: float64(2), object(12)
# memory usage: 2.3+ MB

# %%
df.shape
# Out:
# (21864, 14)

# %%
df.columns = df.columns.str.strip()

# %%
df["PURCHASE_TS"] = pd.to_datetime(df["PURCHASE_TS"], errors = 'coerce')
df["REFUND_TS"] = pd.to_datetime(df["REFUND_TS"], errors = 'coerce')
df["SHIP_TS"] = pd.to_datetime(df["SHIP_TS"], errors = 'coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21864 entries, 0 to 21863
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   USER_ID                  21864 non-null  object
#  1   ORDER_ID                 21864 non-null  object
#  2   PURCHASE_TS              21853 non-null  datetime64[ns]
#  3   SHIP_TS                  21864 non-null  datetime64[ns]
#  4   REFUND_TS                3487 non-null   datetime64[ns]
#  5   PRODUCT_NAME             21864 non-null  object
#  6   PRODUCT_ID               21864 non-null  object
#  7   USD_PRICE                21859 non-null  float64
#  8   PURCHASE_PLATFORM        21864 non-null  object
#  9   MARKETING_CHANNEL        21781 non-null  object
#  10  ACCOUNT_CREATION_METHOD  21781 non-null  object
#  11  COUNTRY_CODE             21826 non-null  object
#  12  Unnamed: 12              0 non-null      float64
#  13  Unnamed: 13              1 non-null      object
# dtypes: datetime64[ns](3), float64(2), object(9)
# memory usage: 2.3+ MB

# %%
df = df.drop(["Unnamed: 12", "Unnamed: 13"], axis = 1)

# %%
df.head()
# Out:
#     USER_ID           ORDER_ID PURCHASE_TS    SHIP_TS  REFUND_TS  \
# 0  2c06175e   0001328c3c220830  2020-12-24 2020-12-13        NaT
# 1  ee8e5bc2  0002af7a5c6100772  2020-10-01 2020-09-21        NaT
# 2  9eb4efe0   0002b8350e167074  2020-04-21 2020-02-16        NaT
# 3  cac7cbaf   0006d06b98385729  2020-04-07 2020-04-04 2022-04-28
# 4  6b0230bc   00097279a2f46150  2020-11-24 2020-08-02        NaT
#
#                 PRODUCT_NAME PRODUCT_ID  USD_PRICE PURCHASE_PLATFORM  \
# 0            Nintendo Switch       e682     168.00           website
# 1            Nintendo Switch       e682     160.61           website
# 2            Nintendo Switch       8d0d     151.20           website
# 3  Sony PlayStation 5 Bundle       54ed    1132.82           website
# 4            Nintendo Switch       8d0d      33.89           website
#
#   MARKETING_CHANNEL ACCOUNT_CREATION_METHOD COUNTRY_CODE
# 0         affiliate                 unknown           US
# 1            direct                 desktop           DE
# 2            direct                 desktop           US
# 3            direct                 desktop           AU
# 4            direct                 desktop           TR

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#     USER_ID           ORDER_ID PURCHASE_TS    SHIP_TS  REFUND_TS  \
# 0  2c06175e   0001328c3c220830  2020-12-24 2020-12-13        NaT
# 1  ee8e5bc2  0002af7a5c6100772  2020-10-01 2020-09-21        NaT
# 2  9eb4efe0   0002b8350e167074  2020-04-21 2020-02-16        NaT
# 3  cac7cbaf   0006d06b98385729  2020-04-07 2020-04-04 2022-04-28
# 4  6b0230bc   00097279a2f46150  2020-11-24 2020-08-02        NaT
#
#                 PRODUCT_NAME PRODUCT_ID  USD_PRICE PURCHASE_PLATFORM  \
# 0            Nintendo Switch       e682     168.00           website
# 1            Nintendo Switch       e682     160.61           website
# 2            Nintendo Switch       8d0d     151.20           website
# 3  Sony PlayStation 5 Bundle       54ed    1132.82           website
# 4            Nintendo Switch       8d0d      33.89           website
#
#   MARKETING_CHANNEL ACCOUNT_CREATION_METHOD COUNTRY_CODE
# 0         affiliate                 unknown           US
# 1            direct                 desktop           DE
# 2            direct                 desktop           US
# 3            direct                 desktop           AU
# 4            direct                 desktop           TR

# %%
df["USER_ID"] = df["USER_ID"].str.strip()

# %%
df["PRODUCT_NAME"] = df["PRODUCT_NAME"].str.strip().str.replace("27in 4K gaming monitor", "27inches 4k gaming monitor")
df["PRODUCT_NAME"].value_counts()
# Out:
# PRODUCT_NAME
# Nintendo Switch                   10386
# 27inches 4k gaming monitor         4688
# JBL Quantum 100 Gaming Headset     4296
# Sony PlayStation 5 Bundle           977
# Dell Gaming Mouse                   719
# Lenovo IdeaPad Gaming 3             669
# Acer Nitro V Gaming Laptop           87
# Razer Pro Gaming Headset              7
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# USER_ID                        0
# ORDER_ID                       0
# PURCHASE_TS                   11
# SHIP_TS                        0
# REFUND_TS                  18346
# PRODUCT_NAME                   0
# PRODUCT_ID                     0
# USD_PRICE                      5
# PURCHASE_PLATFORM              0
# MARKETING_CHANNEL             83
# ACCOUNT_CREATION_METHOD       83
# COUNTRY_CODE                  38
# dtype: int64

# %%
df["MARKETING_CHANNEL"]=df["MARKETING_CHANNEL"].fillna("unknown")

# %%
df["ACCOUNT_CREATION_METHOD"] = df["ACCOUNT_CREATION_METHOD"].fillna("unknown")

# %%
df["COUNTRY_CODE"] = df["COUNTRY_CODE"].fillna("unknown")

# %%
df.isna().sum()
# Out:
# USER_ID                        0
# ORDER_ID                       0
# PURCHASE_TS                   11
# SHIP_TS                        0
# REFUND_TS                  18346
# PRODUCT_NAME                   0
# PRODUCT_ID                     0
# USD_PRICE                      5
# PURCHASE_PLATFORM              0
# MARKETING_CHANNEL              0
# ACCOUNT_CREATION_METHOD        0
# COUNTRY_CODE                   0
# dtype: int64

# %%
row_to_drop = df.loc[df["USD_PRICE"].isna(), :]
df.dropna(subset = "USD_PRICE", inplace = True)

# %%
df.shape
# Out:
# (21824, 12)

# %%
usd_0 = df.loc[df["USD_PRICE"] == 0, :]
usd_0.shape
# Out:
# (29, 12)

# %%
df = df[df["USD_PRICE"] !=0]

# %%
df.shape
# Out:
# (21795, 12)

# %%
product_detail = df.groupby("PRODUCT_NAME")["USD_PRICE"].sum().sort_values(ascending = False)
product_detail.plot(kind = 'bar')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("")
plt.ylabel("")
plt.ticklabel_format(style = 'plain', axis = 'y')

# %%
df2 = pd.read_csv(r"C:\Users\user\OneDrive\桌面\Data Analysis Projects\Python\Gamezone_project\country_name.csv")

# %%
df2.head()
# Out:
#   COUNTRY_CODE REGION
# 0           AD   EMEA
# 1           AE   EMEA
# 2           AG    NaN
# 3           AI    NaN
# 4           AL   EMEA

# %%
df2.isna().sum()
# Out:
# COUNTRY_CODE    808
# REGION          830
# dtype: int64

# %%
df2.shape
# Out:
# (999, 2)

# %%
df2[df2["COUNTRY_CODE"].isna()]
# Out:
#     COUNTRY_CODE REGION
# 129          NaN   EMEA
# 192          NaN    NaN
# 193          NaN    NaN
# 194          NaN    NaN
# 195          NaN    NaN
# ..           ...    ...
# 994          NaN    NaN
# 995          NaN    NaN
# 996          NaN    NaN
# 997          NaN    NaN
# 998          NaN    NaN
#
# [808 rows x 2 columns]

# %%
df2 = df2.dropna(subset =["COUNTRY_CODE", "REGION"], how = 'all')

# %%
df2.shape
# Out:
# (192, 2)

# %%
df2[df2["COUNTRY_CODE"].isna()]
# Out:
#     COUNTRY_CODE REGION
# 129          NaN   EMEA

# %%
df2[df2["REGION"].isna()]
# Out:
#     COUNTRY_CODE REGION
# 2             AG    NaN
# 3             AI    NaN
# 25            BQ    NaN
# 27            BS    NaN
# 44            CW    NaN
# 61            GD    NaN
# 67            GL    NaN
# 69            GP    NaN
# 80            IE    NaN
# 89            JM    NaN
# 95            KN    NaN
# 98            KY    NaN
# 101           LB    NaN
# 102           LC    NaN
# 120           MQ    NaN
# 145           PR    NaN
# 166           SX    NaN
# 167           TC    NaN
# 174           TT    NaN
# 179           US    NaN
# 182           VC    NaN
# 184           VG    NaN
# 185           VI    NaN

# %%
df2["REGION"].unique()
# Out:
# array(['EMEA', nan, 'APAC', 'LATAM', 'North America', 'X.x'], dtype=object)

# %%
df2["REGION"] = df2["REGION"].str.replace("North America", "US")

# %%
df2["REGION"].unique()
# Out:
# array(['EMEA', nan, 'APAC', 'LATAM', 'US', 'X.x'], dtype=object)

# %%
region_map = {
    'AG': 'US', 'AI': 'US', 'BQ': 'US', 'BS': 'US',
    'CW': 'US', 'GD': 'US', 'GL': 'US', 'GP': 'US',
    'IE': 'Europe', 'JM': 'US', 'KN': 'US', 'KY': 'US',
    'LB': 'Asia',   'LC': 'US', 'MQ': 'US', 'PR': 'US',
    'SX': 'US', 'TC': 'US', 'TT': 'US', 'US': 'US',
    'VC': 'US', 'VG': 'US', 'VI': 'US'
}

# %%
df2['REGION'] = df2['COUNTRY_CODE'].map(region_map).fillna(df2['REGION'])

# %%
df2[df2["REGION"].isna()]
# Out:
# Empty DataFrame
# Columns: [COUNTRY_CODE, REGION]
# Index: []

# %%
df2[df2["REGION"] == "X.x"]
# Out:
#     COUNTRY_CODE REGION
# 113           MH    X.x
# 141           PG    X.x

# %%
df2["REGION"] = df2["REGION"].str.replace("X.x", "APAC")
df2["REGION"] = df2["REGION"].str.replace("Asia", "APAC")
df2["REGION"] = df2["REGION"].str.replace("Europe", "EMEA")

# %%
df2["REGION"].unique()
# Out:
# array(['EMEA', 'US', 'APAC', 'LATAM'], dtype=object)

# %%
df2["REGION"].value_counts()
# Out:
# REGION
# EMEA     99
# APAC     45
# US       26
# LATAM    22
# Name: count, dtype: int64

# %%
df = df.merge(df2, on = "COUNTRY_CODE", how="left")

# %%
df.groupby("REGION")["USD_PRICE"].sum().sort_values(ascending = False)
# Out:
# REGION
# US       3195687.36
# EMEA     1859387.34
# APAC      742835.72
# LATAM     335142.77
# Name: USD_PRICE, dtype: float64

# %%
df.groupby("PRODUCT_NAME")["USD_PRICE"].sum().sort_values(ascending = False)
# Out:
# PRODUCT_NAME
# 27inches 4k gaming monitor        1954047.08
# Nintendo Switch                   1658717.65
# Sony PlayStation 5 Bundle         1589243.85
# Lenovo IdeaPad Gaming 3            735506.56
# JBL Quantum 100 Gaming Headset      96197.67
# Acer Nitro V Gaming Laptop          65661.18
# Dell Gaming Mouse                   36490.01
# Razer Pro Gaming Headset              884.23
# Name: USD_PRICE, dtype: float64

# %%
df.describe()
# Out:
#                          PURCHASE_TS                        SHIP_TS  \
# count                          21784                          21795
# mean   2020-04-20 22:22:45.699596032  2020-04-15 22:07:44.803854080
# min              2019-01-01 00:00:00            2018-10-18 00:00:00
# 25%              2019-11-19 00:00:00            2019-11-12 00:00:00
# 50%              2020-05-29 00:00:00            2020-05-23 00:00:00
# 75%              2020-10-12 00:00:00            2020-10-06 00:00:00
# max              2021-02-28 00:00:00            2021-11-16 00:00:00
# std                              NaN                            NaN
#
#                            REFUND_TS     USD_PRICE
# count                           3481  21795.000000
# mean   2022-12-11 12:27:55.380637696    281.566792
# min              2020-11-28 00:00:00      6.110000
# 25%              2022-03-31 00:00:00    126.090000
# 50%              2022-09-20 00:00:00    168.000000
# 75%              2023-05-03 00:00:00    355.135000
# max              2026-03-14 00:00:00   3146.880000
# std                              NaN    366.640154

# %%
df[df['PURCHASE_TS'] > df['SHIP_TS']]
# Out:
#        USER_ID           ORDER_ID PURCHASE_TS    SHIP_TS  REFUND_TS  \
# 0     2c06175e   0001328c3c220830  2020-12-24 2020-12-13        NaT
# 1     ee8e5bc2  0002af7a5c6100772  2020-10-01 2020-09-21        NaT
# 2     9eb4efe0   0002b8350e167074  2020-04-21 2020-02-16        NaT
# 3     cac7cbaf   0006d06b98385729  2020-04-07 2020-04-04 2022-04-28
# 4     6b0230bc   00097279a2f46150  2020-11-24 2020-08-02        NaT
# ...        ...                ...         ...        ...        ...
# 1998  401bbee3   1a1847f6bfd29041  2020-11-28 2020-11-11        NaT
# 1999  7a0b60a8   1a2726958f252145  2020-03-13 2020-01-31        NaT
# 2000  4f1b9c81   1a31374f33e35093  2020-10-07 2020-07-18        NaT
# 2001  54d69a48   1a313fc2aba37344  2019-04-05 2019-02-25        NaT
# 2002  ffb70dda  1a32039b848108003  2020-11-17 2020-07-15 2021-07-26
#
#                         PRODUCT_NAME PRODUCT_ID  USD_PRICE PURCHASE_PLATFORM  \
# 0                    Nintendo Switch       e682     168.00           website
# 1                    Nintendo Switch       e682     160.61           website
# 2                    Nintendo Switch       8d0d     151.20           website
# 3          Sony PlayStation 5 Bundle       54ed    1132.82           website
# 4                    Nintendo Switch       8d0d      33.89           website
# ...                              ...        ...        ...               ...
# 1998  JBL Quantum 100 Gaming Headset       ab0f      24.00           website
# 1999  JBL Quantum 100 Gaming Headset       ab0f      24.31           website
# 2000      27inches 4k gaming monitor       e7e6     435.86           website
# 2001  JBL Quantum 100 Gaming Headset       ab0f      21.73           website
# 2002      27inches 4k gaming monitor       e7e6     480.00           website
#
#      MARKETING_CHANNEL ACCOUNT_CREATION_METHOD COUNTRY_CODE REGION
# 0            affiliate                 unknown           US     US
# 1               direct                 desktop           DE   EMEA
# 2               direct                 desktop           US     US
# 3               direct                 desktop           AU   APAC
# 4               direct                 desktop           TR   EMEA
# ...                ...                     ...          ...    ...
# 1998            direct                 desktop           US     US
# 1999            direct                 desktop           IT   EMEA
# 2000            direct                 desktop           IT   EMEA
# 2001            direct                 desktop           KR   APAC
# 2002            direct                 desktop           PE  LATAM
#
# [1992 rows x 13 columns]

# %%
df['purchase_month'] = df['PURCHASE_TS'].dt.month
df = df.dropna(subset = 'purchase_month')

# %%
top_3 = df.groupby("PRODUCT_NAME")["USD_PRICE"].sum().nlargest(3).index
df_pivot = df.pivot_table(index = 'purchase_month', columns = 'PRODUCT_NAME', values = 'USD_PRICE', aggfunc = 'sum')
df_top3 = df_pivot[top_3]
df_top3.plot()
plt.legend(bbox_to_anchor = (1, 1.2),loc = 'upper right')

# %%
df.groupby('PURCHASE_PLATFORM')["USD_PRICE"].sum().sort_values()
# Out:
# PURCHASE_PLATFORM
# mobile app     153927.78
# website       5979864.40
# Name: USD_PRICE, dtype: float64

# %%
df_normal = df[(df['SHIP_TS'] - df['PURCHASE_TS']).astype(int) >= 0].copy()
df_normal
# Out:
#         USER_ID           ORDER_ID PURCHASE_TS    SHIP_TS REFUND_TS  \
# 84     6eee6248   01109e7002147835  2020-06-20 2020-06-20       NaT
# 318    e31911a4   040f635a51595929  2020-06-12 2020-06-12       NaT
# 416    821c1406   0551110c7b755483  2020-03-12 2020-03-13       NaT
# 985    0cf75a8d    0d06d15e8c48315  2019-11-22 2019-11-23       NaT
# 1151   582cc3ee   0f217c65f0a38617  2019-12-09 2019-12-09       NaT
# ...         ...                ...         ...        ...       ...
# 21790  e432cf6f   fff0b6a1e9996384  2019-11-27 2019-11-29       NaT
# 21791  f4f11c04  fff4592dc6d103535  2019-12-23 2019-12-26       NaT
# 21792  f4f11c04  fff4592dc6d103537  2019-12-23 2019-12-26       NaT
# 21793  203ce4dd   fff829b061e16171  2021-01-31 2021-02-02       NaT
# 21794  203ce4dd   fff829b061e16172  2021-01-31 2021-02-02       NaT
#
#                          PRODUCT_NAME PRODUCT_ID  USD_PRICE PURCHASE_PLATFORM  \
# 84                    Nintendo Switch       8d0d     152.51           website
# 318    JBL Quantum 100 Gaming Headset       ab0f      24.00           website
# 416         Sony PlayStation 5 Bundle       54ed    1800.00           website
# 985        27inches 4k gaming monitor       891b     312.92           website
# 1151   JBL Quantum 100 Gaming Headset       ab0f      24.00           website
# ...                               ...        ...        ...               ...
# 21790       Sony PlayStation 5 Bundle       54ed    1527.06           website
# 21791      27inches 4k gaming monitor       891b     467.88           website
# 21792      27inches 4k gaming monitor       891b     467.88           website
# 21793               Dell Gaming Mouse       8d4f      67.07        mobile app
# 21794               Dell Gaming Mouse       8d4f      67.07        mobile app
#
#       MARKETING_CHANNEL ACCOUNT_CREATION_METHOD COUNTRY_CODE REGION  \
# 84               direct                 desktop           FR   EMEA
# 318              direct                 desktop           US     US
# 416              direct                 desktop           US     US
# 985              direct                 desktop           US     US
# 1151             direct                 desktop           US     US
# ...                 ...                     ...          ...    ...
# 21790            direct                 desktop           US     US
# 21791            direct                 desktop           US     US
# 21792            direct                 desktop           US     US
# 21793            direct                 desktop           GB   EMEA
# 21794            direct                 desktop           GB   EMEA
#
#        purchase_month
# 84                6.0
# 318               6.0
# 416               3.0
# 985              11.0
# 1151             12.0
# ...               ...
# 21790            11.0
# 21791            12.0
# 21792            12.0
# 21793             1.0
# 21794             1.0
#
# [19792 rows x 14 columns]

# %%
df_normal.groupby("REGION")["USD_PRICE"].sum().sort_values(ascending = False)
# Out:
# REGION
# US       2893623.70
# EMEA     1677984.04
# APAC      685134.31
# LATAM     310219.62
# Name: USD_PRICE, dtype: float64

# %%
df_normal_top3 = df_normal.groupby("PRODUCT_NAME")["USD_PRICE"].sum().nlargest(3).index
df_normal_product_pivot = df_normal.pivot_table(index = "purchase_month", columns = "PRODUCT_NAME", values = "USD_PRICE", aggfunc = 'sum')
df_normal_product_pivot[df_normal_top3].plot(kind = 'line')
# Out:
# <Axes: xlabel='purchase_month'>

# %%
df_normal.groupby("PRODUCT_NAME")["USD_PRICE"].sum().sort_values(ascending = False)
# Out:
# PRODUCT_NAME
# 27inches 4k gaming monitor        1767820.35
# Nintendo Switch                   1507787.74
# Sony PlayStation 5 Bundle         1454610.00
# Lenovo IdeaPad Gaming 3            661085.48
# JBL Quantum 100 Gaming Headset      87370.26
# Acer Nitro V Gaming Laptop          57790.42
# Dell Gaming Mouse                   33223.51
# Razer Pro Gaming Headset              764.25
# Name: USD_PRICE, dtype: float64

# %%
website_volume = df_normal[df_normal["PURCHASE_PLATFORM"]=='website']["USD_PRICE"].sum()
mobile_volume = df_normal[df_normal["PURCHASE_PLATFORM"]=='mobile app']["USD_PRICE"].sum()
print(website_volume)
print(mobile_volume)
print(website_volume / (website_volume+mobile_volume))
# Out:
# 5432967.350000001
# 137484.66
# 0.9753189400513298

# %%
df_normal["ship_diff"] = df_normal["SHIP_TS"] - df_normal["PURCHASE_TS"]
df_normal["ship_diff"].describe()
# Out:
# count                        19792
# mean     1 days 23:58:54.518997574
# std      0 days 19:40:20.097741260
# min                0 days 00:00:00
# 25%                1 days 00:00:00
# 50%                2 days 00:00:00
# 75%                3 days 00:00:00
# max                3 days 00:00:00
# Name: ship_diff, dtype: object

# %%
df_normal_refunded = pd.notna(df_normal["REFUND_TS"])
df_normal[df_normal_refunded]["ship_diff"].describe()
df_normal[df_normal_refunded]["ship_diff"].value_counts()
# Out:
# ship_diff
# 3 days    1079
# 1 days    1060
# 2 days    1058
# Name: count, dtype: int64

# %%
sns.countplot(data = df_normal, x = "ship_diff")
# Out:
# <Axes: xlabel='ship_diff', ylabel='count'>

# %%
sns.countplot(data = df_normal[df_normal_refunded], x = "ship_diff")
# Out:
# <Axes: xlabel='ship_diff', ylabel='count'>

# %%
refunded_orders = df_normal[df_normal["REFUND_TS"].notna()].copy()
refunded_orders.set_index('REFUND_TS', inplace = True)
refund_trend = refunded_orders['ORDER_ID'].resample('ME').count()
refund_trend.plot(kind = 'line', marker = 'o')
# Out:
# <Axes: xlabel='REFUND_TS'>

# %%
df_normal[["USER_ID", "ORDER_ID"]].nunique()
# Out:
# USER_ID     18026
# ORDER_ID    19682
# dtype: int64

# %%
duplicate_orders = df_normal[df_normal.duplicated(subset = "ORDER_ID", keep = False)]
duplicate_orders
# Out:
#         USER_ID          ORDER_ID PURCHASE_TS    SHIP_TS  REFUND_TS  \
# 9903   e80b93ad  815caec5eb998020  2020-01-30 2020-01-31        NaT
# 9904   e80b93ad  815caec5eb998020  2020-01-30 2020-01-31        NaT
# 13471  3bb56d71  add88586a5827183  2020-01-22 2020-01-23        NaT
# 13472  3bb56d71  add88586a5827183  2020-01-22 2020-01-23        NaT
# 18850  52e2062d  e44ebe4eed936564  2021-02-10 2021-02-11        NaT
# ...         ...               ...         ...        ...        ...
# 21666   b0a2896  fecc9d6766231653  2021-02-22 2021-02-25        NaT
# 21673  e69c1f1e  fede5c24b0797422  2021-02-23 2021-02-25 2026-03-14
# 21674   9c12903  fede5c24b0797422  2021-02-23 2021-02-25 2026-03-14
# 21682  ebf6f56d  fef061c2a1499684  2021-02-06 2021-02-09        NaT
# 21683   f6f3685  fef061c2a1499684  2021-02-06 2021-02-09        NaT
#
#                      PRODUCT_NAME PRODUCT_ID  USD_PRICE PURCHASE_PLATFORM  \
# 9903   27inches 4k gaming monitor       891b     408.20           website
# 9904   27inches 4k gaming monitor       891b     408.20           website
# 13471  27inches 4k gaming monitor       891b     484.89           website
# 13472  27inches 4k gaming monitor       891b     484.89           website
# 18850             Nintendo Switch       e682     102.88           website
# ...                           ...        ...        ...               ...
# 21666             Nintendo Switch       8d0d     184.90           website
# 21673             Nintendo Switch       8d0d     142.80           website
# 21674             Nintendo Switch       8d0d     142.80           website
# 21682             Nintendo Switch       e682     164.42           website
# 21683             Nintendo Switch       e682     164.42           website
#
#       MARKETING_CHANNEL ACCOUNT_CREATION_METHOD COUNTRY_CODE REGION  \
# 9903              email                  mobile           DE   EMEA
# 9904              email                 desktop           DE   EMEA
# 13471             email                  mobile           GB   EMEA
# 13472             email                 desktop           GB   EMEA
# 18850            direct                 desktop           MX  LATAM
# ...                 ...                     ...          ...    ...
# 21666            direct                 desktop           GB   EMEA
# 21673            direct                 desktop           US     US
# 21674            direct                 desktop           US     US
# 21682            direct                 desktop           ES   EMEA
# 21683            direct                 desktop           ES   EMEA
#
#        purchase_month ship_diff
# 9903              1.0    1 days
# 9904              1.0    1 days
# 13471             1.0    1 days
# 13472             1.0    1 days
# 18850             2.0    1 days
# ...               ...       ...
# 21666             2.0    3 days
# 21673             2.0    2 days
# 21674             2.0    2 days
# 21682             2.0    3 days
# 21683             2.0    3 days
#
# [220 rows x 15 columns]

# %%
region_total_revenue = df_normal.groupby("REGION")["USD_PRICE"].sum()
region_total_orders = df_normal.groupby("REGION")["ORDER_ID"].size()
AOV = region_total_revenue / region_total_orders
AOV.plot()
AOV
# Out:
# REGION
# APAC     290.557383
# EMEA     277.352734
# LATAM    274.530637
# US       283.299755
# dtype: float64

# %%
region_time_pivot = df_normal.pivot_table(index = "PURCHASE_TS", columns = "REGION", values = "USD_PRICE", aggfunc = "sum")
region_month = region_time_pivot.resample('ME').sum()
region_month.plot(kind = 'line')
# Out:
# <Axes: xlabel='PURCHASE_TS'>

# %%
region_country_detail = df_normal.groupby(['REGION', "COUNTRY_CODE"])["USD_PRICE"].sum().nlargest(10).sort_values(ascending = False)
region_country_detail.sort_values().plot(kind = 'barh', figsize = (15,6))
plt.xticks([0, 500000, 1000000, 1500000, 2000000, 2500000], ['0', '500K', '1M', '1.5M', '2M', '2.5M'])
# Out:
# ([<matplotlib.axis.XTick at 0x224ec1fe990>,
#   <matplotlib.axis.XTick at 0x224ec1fd810>,
#   <matplotlib.axis.XTick at 0x224ec26e0d0>,
#   <matplotlib.axis.XTick at 0x224ec26e850>,
#   <matplotlib.axis.XTick at 0x224ec26efd0>,
#   <matplotlib.axis.XTick at 0x224ec26f750>],
#  [Text(0, 0, '0'),
#   Text(500000, 0, '500K'),
#   Text(1000000, 0, '1M'),
#   Text(1500000, 0, '1.5M'),
#   Text(2000000, 0, '2M'),
#   Text(2500000, 0, '2.5M')])

# %%
region_country_refund = df_normal.groupby(["REGION", "COUNTRY_CODE"])["REFUND_TS"].size().sort_values(ascending = False)
df_refunds_only = df_normal[df_normal["REFUND_TS"].notna()].copy()
top_10_refund = df_refunds_only.groupby("COUNTRY_CODE")["USD_PRICE"].sum().nlargest(10).index
region_country_refund_pivot = df_refunds_only.pivot_table(index = "REGION", columns = "COUNTRY_CODE", values = "USD_PRICE", aggfunc = 'sum' )
top_10_pivot = region_country_refund_pivot.loc[:, top_10_refund]
top_10_pivot.plot(kind = 'barh', stacked = True)
# Out:
# <Axes: ylabel='REGION'>

# %%
refunded_orders
# Out:
#              USER_ID          ORDER_ID PURCHASE_TS    SHIP_TS  \
# REFUND_TS
# 2021-12-18  89810780   1a4fb45f72d2374  2019-12-20 2019-12-23
# 2021-03-30  94c7b0da  1a62e4d594f63043  2019-04-08 2019-04-10
# 2022-06-03  b4191dfd  1a7861024ca76332  2020-07-03 2020-07-06
# 2024-03-24  d3baaa47  1a867aad6a389398  2020-11-13 2020-11-14
# 2022-06-13  8856f49e  1aafa23bc3857920  2020-05-03 2020-05-06
# ...              ...               ...         ...        ...
# 2022-03-05  b013916a  ff7ff68f03a74626  2021-01-27 2021-01-30
# 2022-05-13  19c98e16  ff833b3ec5f13477  2021-01-14 2021-01-15
# 2022-09-17  03fe6245   ff8872788474792  2020-08-21 2020-08-22
# 2022-08-26  b9a9b776  ff91b99dc7878667  2020-09-12 2020-09-15
# 2023-01-11  5444ffa9  ffeb3ac2f3737125  2020-12-20 2020-12-23
#
#                               PRODUCT_NAME PRODUCT_ID  USD_PRICE  \
# REFUND_TS
# 2021-12-18      27inches 4k gaming monitor       891b     480.00
# 2021-03-30                 Nintendo Switch       8d0d     178.74
# 2022-06-03       Sony PlayStation 5 Bundle       54ed    1800.00
# 2024-03-24                 Nintendo Switch       e682     168.00
# 2022-06-13                 Nintendo Switch       8d0d     168.00
# ...                                    ...        ...        ...
# 2022-03-05      27inches 4k gaming monitor       891b     480.00
# 2022-05-13                 Nintendo Switch       8d0d     164.88
# 2022-09-17                 Nintendo Switch       8d0d     142.63
# 2022-08-26  JBL Quantum 100 Gaming Headset       ab0f      24.00
# 2023-01-11      27inches 4k gaming monitor       e7e6     506.46
#
#            PURCHASE_PLATFORM MARKETING_CHANNEL ACCOUNT_CREATION_METHOD  \
# REFUND_TS
# 2021-12-18           website         affiliate                 unknown
# 2021-03-30           website            direct                 desktop
# 2022-06-03           website            direct                 desktop
# 2024-03-24           website             email                 desktop
# 2022-06-13           website            direct                 desktop
# ...                      ...               ...                     ...
# 2022-03-05           website             email                 desktop
# 2022-05-13           website            direct                 desktop
# 2022-09-17           website            direct                 desktop
# 2022-08-26           website            direct                 desktop
# 2023-01-11           website            direct                 desktop
#
#            COUNTRY_CODE REGION  purchase_month ship_diff
# REFUND_TS
# 2021-12-18           US     US            12.0    3 days
# 2021-03-30           GB   EMEA             4.0    2 days
# 2022-06-03           TH   APAC             7.0    3 days
# 2024-03-24           US     US            11.0    1 days
# 2022-06-13           US     US             5.0    3 days
# ...                 ...    ...             ...       ...
# 2022-03-05           US     US             1.0    3 days
# 2022-05-13           DE   EMEA             1.0    1 days
# 2022-09-17           AU   APAC             8.0    1 days
# 2022-08-26           EG   EMEA             9.0    3 days
# 2023-01-11           GB   EMEA            12.0    3 days
#
# [3197 rows x 14 columns]
